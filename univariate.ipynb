# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %%

# %%
df = pd.read_csv("Iris.csv")

df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#df.drop(["Id"],axis=1)
df.drop(columns="Id")
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df_setosa = df.loc[df["Species"]=="Iris-setosa"]
df_virginica = df.loc[df["Species"]=="Iris-virginica"]
df_vesicolor = df.loc[df["Species"]=="Iris-versicolor"]

# %%
plt.plot(df_setosa["SepalLengthCm"]),np.zeros_like(df_setosa["SepalLengthCm"])
plt.plot(df_vesicolor["SepalLengthCm"]),np.zeros_like(df_vesicolor["SepalLengthCm"])
plt.plot(df_virginica['SepalLengthCm']),np.zeros_like(df_virginica['SepalLengthCm'])
plt.legend()
plt.xlabel("petal length")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_16900\2036196138.py:4: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
###Bivariate Analysis
sns.FacetGrid(df,hue="Species").map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()

# %%
sns.FacetGrid(df,hue="Species").map(plt.scatter,"PetalLengthCm","PetalWidthCm").add_legend()

# %%
## Multivariate Analysis
sns.pairplot(df,hue="Species",size=4)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(df)
